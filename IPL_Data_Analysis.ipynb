# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('deliveries.csv')
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %% [markdown]
# ###perform indepth analysis for DA warner batsmen.

# %%
filt=df['batsman']=='DA Warner'
df_warner=df[filt]
df_warner.shape
# Out:
# (2902, 21)

# %%
df_warner['dismissal_kind'].value_counts().plot.bar()

# %%
df_warner['dismissal_kind'].value_counts().plot.pie()

# %%
len(df_warner[df_warner['batsman_runs']==4])  #hit fours
# Out:
# 401

# %%
six=df_warner[df['batsman_runs']==6]   #hit six
len(six)
# Out:
# <ipython-input-37-74f01988cc00>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   six=df_warner[df['batsman_runs']==6]   #hit six
# 160

# %%
def count(df,runs):
    return len(df_warner[df_warner['batsman_runs']==runs])*runs

# %%
count(df_warner,1)
# Out:
# 997

# %%
count(df_warner,2)
# Out:
# 414

# %%
count(df_warner,3)
# Out:
# 39

# %%
count(df_warner,4)
# Out:
# 1604

# %%
count(df_warner,6)
# Out:
# 960

# %%
list=[997,414,39,1604,960]
labels=[1,2,3,4,6]
exploid=[0,0,0,0.1,0]
plt.pie(list,labels=labels,autopct='%1.1ff%%',radius=1,explode=exploid)
# Out:
# ([<matplotlib.patches.Wedge at 0xf738ef42b0>,
# ...
#  [Text(0.7817643705069365, 0.7738504177203069, '1'),
#   Text(-0.33959111687520577, 1.0462685474291247, '2'),
#   Text(-0.6816960876596443, 0.863302058418451, '3'),
#   Text(-1.1128316125234867, -0.44900534759440974, '4'),
#   Text(0.8038429148449225, -0.750890516822272, '6')],
#  [Text(0.4264169293674199, 0.4221002278474401, '24.8f%'),
#   Text(-0.18523151829556675, 0.5706919349613407, '10.3f%'),
#   Text(-0.3718342296325332, 0.4708920318646096, '1.0f%'),
#   Text(-0.6491517739720338, -0.261919786096739, '40.0f%'),
#   Text(0.4384597717335941, -0.4095766455394211, '23.9f%')])

# %% [markdown]
# ###score distribution for teams by innings.

# %%
df['bowling_team'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiant', 'Mumbai Indians',
#        'Kolkata Knight Riders', 'Gujarat Lions', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Deccan Chargers', 'Kochi Tuskers Kerala', 'Pune Warriors',
#        'Rising Pune Supergiants'], dtype=object)

# %%
Teams={
    'Royal Challengers Bangalore':'RCB', 'Sunrisers Hyderabad':'SH',
       'Rising Pune Supergiant':'RPS', 'Mumbai Indians':'MI',
       'Kolkata Knight Riders':'KKR', 'Gujarat Lions':'GL', 'Kings XI Punjab':'KXP',
       'Delhi Daredevils':'DD', 'Chennai Super Kings':'CSK', 'Rajasthan Royals':'RR',
       'Deccan Chargers':'DC', 'Kochi Tuskers Kerala':'KTK', 'Pune Warriors':'PW',
       'Rising Pune Supergiants':'RPS'
}

# %%
df['batting_team']=df['batting_team'].map(Teams)
df['bowling_team']=df['bowling_team'].map(Teams)

# %%
df.head()
# Out:
#    match_id  inning batting_team bowling_team  over  ball    batsman  \
# 0         1       1           SH          RCB     1     1  DA Warner
# 1         1       1           SH          RCB     1     2  DA Warner
# 2         1       1           SH          RCB     1     3  DA Warner
# 3         1       1           SH          RCB     1     4  DA Warner
# 4         1       1           SH          RCB     1     5  DA Warner
#
#   non_striker    bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 0    S Dhawan  TS Mills              0  ...         0            0
# 1    S Dhawan  TS Mills              0  ...         0            0
# 2    S Dhawan  TS Mills              0  ...         0            0
# 3    S Dhawan  TS Mills              0  ...         0            0
# 4    S Dhawan  TS Mills              0  ...         0            0
#
#    noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs  \
# 0            0             0             0           0           0
# ...

# %%
df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
runs=df.groupby(['match_id','inning','batting_team'])['total_runs'].sum().reset_index()
runs.drop('match_id',axis=1,inplace=True)
runs.head()
# Out:
#    inning batting_team  total_runs
# 0       1           SH         207
# 1       2          RCB         172
# 2       1           MI         184
# 3       2          RPS         187
# 4       1           GL         183

# %%
inning1=runs[runs['inning']==1]
inning2=runs[runs['inning']==2]

# %%
sns.boxplot(x='batting_team',y='total_runs',data=inning1)

# %%
sns.boxplot(x='batting_team',y='total_runs',data=inning2)

# %% [markdown]
# ###How many times teams score more then 200?

# %%
high_score=df.groupby(['match_id','inning','batting_team','bowling_team'])['total_runs'].sum().reset_index()
high_score
# Out:
#       match_id  inning batting_team bowling_team  total_runs
# 0            1       1           SH          RCB         207
# 1            1       2          RCB           SH         172
# 2            2       1           MI          RPS         184
# 3            2       2          RPS           MI         187
# 4            3       1           GL          KKR         183
# ...        ...     ...          ...          ...         ...
# 1279       634       2          KKR           SH         140
# 1280       635       1           GL           SH         162
# 1281       635       2           SH           GL         163
# 1282       636       1           SH          RCB         208
# 1283       636       2          RCB           SH         200
#
# [1284 rows x 5 columns]

# %%
score_200=high_score[high_score['total_runs']>=200]
score_200.shape
# Out:
# (67, 5)

# %%
sns.countplot(score_200['batting_team'])

# %%
sns.countplot(score_200['bowling_team'])

# %% [markdown]
# ###top 10 batsman()

# %%
balls=df.groupby('batsman')['ball'].count().reset_index()
balls
# Out:
#             batsman  ball
# 0    A Ashish Reddy   196
# 1        A Chandila     7
# 2          A Chopra    75
# 3       A Choudhary    20
# 4        A Flintoff    57
# ..              ...   ...
# 456     YV Takawale   183
# 457   Yashpal Singh    67
# 458     Younis Khan     7
# 459    Yuvraj Singh  2050
# 460          Z Khan   141
#
# [461 rows x 2 columns]

# %%
runs=df.groupby('batsman')['batsman_runs'].sum().reset_index()
runs
# Out:
#             batsman  batsman_runs
# 0    A Ashish Reddy           280
# 1        A Chandila             4
# 2          A Chopra            53
# 3       A Choudhary            25
# 4        A Flintoff            62
# ..              ...           ...
# 456     YV Takawale           192
# 457   Yashpal Singh            47
# 458     Younis Khan             3
# 459    Yuvraj Singh          2591
# 460          Z Khan           117
#
# [461 rows x 2 columns]

# %%
four=df[df['batsman_runs']==4]
four
# Out:
#         match_id  inning batting_team bowling_team  over  ball        batsman  \
# 2              1       1           SH          RCB     1     3      DA Warner
# 8              1       1           SH          RCB     2     2      DA Warner
# 13             1       1           SH          RCB     2     7   MC Henriques
# 30             1       1           SH          RCB     5     5   MC Henriques
# 32             1       1           SH          RCB     6     1       S Dhawan
# ...          ...     ...          ...          ...   ...   ...            ...
# 150403       636       2          RCB           SH    11     4        V Kohli
# 150407       636       2          RCB           SH    12     2        V Kohli
# 150418       636       2          RCB           SH    14     1       KL Rahul
# 150447       636       2          RCB           SH    18     6    Sachin Baby
# 150459       636       2          RCB           SH    20     6  Iqbal Abdulla
#
# ...

# %%
runs_4=four.groupby('batsman')['batsman_runs'].count().reset_index()
runs_4.columns=['batsman','4s']
runs_4
# Out:
#             batsman   4s
# 0    A Ashish Reddy   16
# 1          A Chopra    7
# 2       A Choudhary    1
# 3        A Flintoff    5
# 4          A Kumble    3
# ..              ...  ...
# 363       YK Pathan  240
# 364     YV Takawale   26
# 365   Yashpal Singh    5
# 366    Yuvraj Singh  205
# 367          Z Khan   11
#
# [368 rows x 2 columns]

# %%
six=df[df['batsman_runs']==6]
six
# Out:
#         match_id  inning batting_team bowling_team  over  ball       batsman  \
# 10             1       1           SH          RCB     2     4     DA Warner
# 47             1       1           SH          RCB     8     4  MC Henriques
# 75             1       1           SH          RCB    13     2  Yuvraj Singh
# 89             1       1           SH          RCB    15     3  Yuvraj Singh
# 91             1       1           SH          RCB    15     5  MC Henriques
# ...          ...     ...          ...          ...   ...   ...           ...
# 150395       636       2          RCB           SH    10     2       V Kohli
# 150413       636       2          RCB           SH    13     2       V Kohli
# 150428       636       2          RCB           SH    15     5     SR Watson
# 150440       636       2          RCB           SH    17     5     STR Binny
# 150453       636       2          RCB           SH    19     6   Sachin Baby
#
# ...

# %%
runs_6=six.groupby('batsman')['batsman_runs'].count().reset_index()
runs_6.columns=['batsman','6s']
runs_6
# Out:
#              batsman   6s
# 0     A Ashish Reddy   15
# 1        A Choudhary    1
# 2         A Flintoff    2
# 3           A Mishra    5
# 4           A Mithun    1
# ..               ...  ...
# 296  Y Venugopal Rao   37
# 297        YK Pathan  149
# 298      YV Takawale    3
# 299     Yuvraj Singh  141
# 300           Z Khan    2
#
# [301 rows x 2 columns]

# %%
player=pd.concat([runs,balls.iloc[:,1],runs_4.iloc[:,1],runs_6.iloc[:,1]],axis=1)
player
# Out:
#             batsman  batsman_runs  ball    4s    6s
# 0    A Ashish Reddy           280   196  16.0  15.0
# 1        A Chandila             4     7   7.0   1.0
# 2          A Chopra            53    75   1.0   2.0
# 3       A Choudhary            25    20   5.0   5.0
# 4        A Flintoff            62    57   3.0   1.0
# ..              ...           ...   ...   ...   ...
# 456     YV Takawale           192   183   NaN   NaN
# 457   Yashpal Singh            47    67   NaN   NaN
# 458     Younis Khan             3     7   NaN   NaN
# 459    Yuvraj Singh          2591  2050   NaN   NaN
# 460          Z Khan           117   141   NaN   NaN
#
# [461 rows x 5 columns]

# %%
player.fillna(0,inplace=True)
player
# Out:
#             batsman  batsman_runs  ball    4s    6s
# 0    A Ashish Reddy           280   196  16.0  15.0
# 1        A Chandila             4     7   7.0   1.0
# 2          A Chopra            53    75   1.0   2.0
# 3       A Choudhary            25    20   5.0   5.0
# 4        A Flintoff            62    57   3.0   1.0
# ..              ...           ...   ...   ...   ...
# 456     YV Takawale           192   183   0.0   0.0
# 457   Yashpal Singh            47    67   0.0   0.0
# 458     Younis Khan             3     7   0.0   0.0
# 459    Yuvraj Singh          2591  2050   0.0   0.0
# 460          Z Khan           117   141   0.0   0.0
#
# [461 rows x 5 columns]

# %%
player['strick_rate']=(player['batsman_runs']/player['ball'])*100
player
# Out:
#             batsman  batsman_runs  ball    4s    6s  strick_rate
# 0    A Ashish Reddy           280   196  16.0  15.0   142.857143
# 1        A Chandila             4     7   7.0   1.0    57.142857
# 2          A Chopra            53    75   1.0   2.0    70.666667
# 3       A Choudhary            25    20   5.0   5.0   125.000000
# 4        A Flintoff            62    57   3.0   1.0   108.771930
# ..              ...           ...   ...   ...   ...          ...
# 456     YV Takawale           192   183   0.0   0.0   104.918033
# 457   Yashpal Singh            47    67   0.0   0.0    70.149254
# 458     Younis Khan             3     7   0.0   0.0    42.857143
# 459    Yuvraj Singh          2591  2050   0.0   0.0   126.390244
# 460          Z Khan           117   141   0.0   0.0    82.978723
#
# [461 rows x 6 columns]

# %%
grp=df.groupby(['match_id','batsman','batting_team'])['batsman_runs'].sum().reset_index()
grp
# Out:
#       match_id       batsman batting_team  batsman_runs
# 0            1   A Choudhary          RCB             6
# 1            1   BCJ Cutting           SH            16
# 2            1      CH Gayle          RCB            32
# 3            1     DA Warner           SH            14
# 4            1      DJ Hooda           SH            16
# ...        ...           ...          ...           ...
# 9510       636     SR Watson          RCB            11
# 9511       636     STR Binny          RCB             9
# 9512       636   Sachin Baby          RCB            18
# 9513       636       V Kohli          RCB            54
# 9514       636  Yuvraj Singh           SH            38
#
# [9515 rows x 4 columns]

# %%
max=grp.groupby('batsman')['batsman_runs'].max().reset_index()
max.columns=['batsman','max_runs']
max
# Out:
#             batsman  max_runs
# 0    A Ashish Reddy        36
# 1        A Chandila         4
# 2          A Chopra        24
# 3       A Choudhary        15
# 4        A Flintoff        24
# ..              ...       ...
# 456     YV Takawale        45
# 457   Yashpal Singh        20
# 458     Younis Khan         3
# 459    Yuvraj Singh        83
# 460          Z Khan        23
#
# [461 rows x 2 columns]

# %%
player2=pd.concat([player,max.iloc[:,1]],axis=1)
player2
# Out:
#             batsman  batsman_runs  ball    4s    6s  strick_rate  max_runs
# 0    A Ashish Reddy           280   196  16.0  15.0   142.857143        36
# 1        A Chandila             4     7   7.0   1.0    57.142857         4
# 2          A Chopra            53    75   1.0   2.0    70.666667        24
# 3       A Choudhary            25    20   5.0   5.0   125.000000        15
# 4        A Flintoff            62    57   3.0   1.0   108.771930        24
# ..              ...           ...   ...   ...   ...          ...       ...
# 456     YV Takawale           192   183   0.0   0.0   104.918033        45
# 457   Yashpal Singh            47    67   0.0   0.0    70.149254        20
# 458     Younis Khan             3     7   0.0   0.0    42.857143         3
# 459    Yuvraj Singh          2591  2050   0.0   0.0   126.390244        83
# 460          Z Khan           117   141   0.0   0.0    82.978723        23
#
# [461 rows x 7 columns]

# %%
max_runs=df.groupby('batsman')['batsman_runs'].sum().nlargest(10).plot.bar()

# %% [markdown]
# ###top individual SCORE BATSMAN.

# %%
df.groupby(['match_id','batsman','batting_team'])['batsman_runs'].sum().reset_index().nlargest(10,'batsman_runs')
# Out:
#       match_id         batsman batting_team  batsman_runs
# 6200       411        CH Gayle          RCB           175
# 900         60     BB McCullum          KKR           158
# 8426       562  AB de Villiers          RCB           133
# 9257       620  AB de Villiers          RCB           129
# 5585       372        CH Gayle          RCB           128
# 3135       206         M Vijay          CSK           127
# 529         36       DA Warner           SH           126
# 7752       516        V Sehwag          KXP           122
# 3686       243     PC Valthaty          KXP           120
# 4223       279        V Sehwag           DD           119

# %% [markdown]
# ###highest wicket taker

# %%
df['dismissal_kind'].unique()
# Out:
# array([nan, 'caught', 'bowled', 'run out', 'lbw', 'caught and bowled',
#        'stumped', 'retired hurt', 'hit wicket', 'obstructing the field'],
#       dtype=object)

# %%
dismissal_kinds=['caught','bowled','lbw','caught and bowled','stumped','hit wicket']

# %%
hwt=df[df['dismissal_kind'].isin(dismissal_kinds)]
hwt
# Out:
#         match_id  inning batting_team bowling_team  over  ball  \
# 11             1       1           SH          RCB     2     5
# 64             1       1           SH          RCB    11     3
# 94             1       1           SH          RCB    16     2
# 116            1       1           SH          RCB    19     4
# 160            1       2          RCB           SH     6     4
# ...          ...     ...          ...          ...   ...   ...
# 150402       636       2          RCB           SH    11     3
# 150416       636       2          RCB           SH    13     5
# 150422       636       2          RCB           SH    14     5
# 150432       636       2          RCB           SH    16     3
# 150438       636       2          RCB           SH    17     3
#
#                batsman     non_striker             bowler  is_super_over  ...  \
# 11           DA Warner        S Dhawan        A Choudhary              0  ...
# ...

# %%
hwt['bowler'].value_counts()[0:10].plot(kind='bar')
